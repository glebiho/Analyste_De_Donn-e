# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
os.chdir(r'C:\Users\DELL\MY IGS WORKSPACE\projet')

# %%
np.linspace(1,9,5)
#1-3 = -2
#3-5 = -2
#5-7 = -2
#7-9 = -2
# Out:
# array([1., 3., 5., 7., 9.])

# %%
x = np.linspace(0, 2, 10)
y = x**2
z = x**3

# %%
#Pour construire une courbe avec X en abscisse et y en ordonnée
plt.plot(x,y)

# %%
#Changer l'épaisseur et la couleur de la ligne du graphique précédemment créé avec le paramètre "c" et "lw"
plt.plot(x, y, c ='green', lw=6)

# %%
plt.plot(x, y, c ='red', lw=7, ls='--')

# %%
#Construire sur le même graphique deux courbes
plt.figure()
plt.plot(x, y, label='x**3')
plt.plot(x, z, label = 'x**2')
plt.title('Graphique 1')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.savefig('figure1.png')# pour enregister l.image du graphique

# %%
#Afficher à travers un boxplot la distribution de x
plt.figure
plt.boxplot(x)
#ajouter un titre au boxplot
plt.title('Ditribution de la variable x')
plt.xlabel('x');

# %%
#Pour construire un nuage de points
plt.scatter(x,z,c='blue')

# %%
#Changer la couleur du graphique
plt.scatter(x, z, c = 'red')

# %%
#labels = ['G1', 'G2', 'G3', 'G4', 'G5']
#men_means = [20, 34, 30, 35, 27]
#women_means = [25, 32, 34, 20, 25]
#w = 0.25
ville=['sikensi','vavoua','abidjan','fresco','agboville','daloa','gagnoa','dabou','guiglo','abengrou','grand_bassam','attinguie']
ventes_b06=[16,23,209,12,80,100,31,11,10,35,54,76]
ventes_b12=[9,3,89,33,44,3,23,43,54,12,9,32]
mois=['janvier','fevrier','mars','avril','mai','juin','juillet','aout','septembre','octobre','novembre','decembre']
print(len(ventes_b06),'\n',len(ventes_b12),'\t',len(ville),'\t',len(mois))
# Out:
# 12
#  12 	 12 	 12

# %%
plt.figure(figsize=(13,7))
plt.hist(mois,ventes_b06)
plt.hist()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [101], in <cell line: 2>()
#       1 plt.figure(figsize=(13,7))
# ----> 2 plt.hist(mois,ventes_b06)
#       3 plt.hist()
#
# File ~\anaconda3\py\lib\site-packages\matplotlib\pyplot.py:2590, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2584 @_copy_docstring_and_deprecators(Axes.hist)
#    2585 def hist(
#    2586         x, bins=None, range=None, density=False, weights=None,
#    2587         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2588         orientation='vertical', rwidth=None, log=False, color=None,
#    2589         label=None, stacked=False, *, data=None, **kwargs):
# -> 2590     return gca().hist(
#    2591         x, bins=bins, range=range, density=density, weights=weights,
#    2592         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    2593         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2594         color=color, label=label, stacked=stacked,
#    2595         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\py\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\py\lib\site-packages\matplotlib\axes\_axes.py:6639, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6635 # Loop through datasets
#    6636 for i in range(nx):
#    6637     # this will automatically overwrite bins,
#    6638     # so that each histogram uses the same bins
# -> 6639     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6640     tops.append(m)
#    6641 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File <__array_function__ internals>:5, in histogram(*args, **kwargs)
#
# File ~\anaconda3\py\lib\site-packages\numpy\lib\histograms.py:793, in histogram(a, bins, range, normed, weights, density)
#     681 r"""
#     682 Compute the histogram of a dataset.
#     683
#    (...)
#     789
#     790 """
#     791 a, weights = _ravel_and_check_weights(a, weights)
# --> 793 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     795 # Histogram is an integer or a float array depending on the weights.
#     796 if weights is None:
#
# File ~\anaconda3\py\lib\site-packages\numpy\lib\histograms.py:431, in _get_bin_edges(a, bins, range, weights)
#     429     bin_edges = np.asarray(bins)
#     430     if np.any(bin_edges[:-1] > bin_edges[1:]):
# --> 431         raise ValueError(
#     432             '`bins` must increase monotonically, when an array')
#     434 else:
#     435     raise ValueError('`bins` must be 1d, when an array')
#
# ValueError: `bins` must increase monotonically, when an array

# %%
plt.figure()
plt.bar(labels, men_means, w, label = "Men")
plt.xlabel('Labels')
plt.ylabel('Effectif')
plt.title("Men vs Women")
plt.legend()

# %%
plt.figure()
plt.bar(labels, men_means, w, label = "Men")
plt.bar(labels, women_means, w, bottom=men_means, label = "Women")
plt.xlabel('Labels')
plt.ylabel('Effectif')
plt.title("Men vs Women")
plt.legend()

# %%
w = 0.4
index_1 = np.arange(len(labels))
print(index_1,'\n')
index_2 = [i+w for i in range(len(labels))]
print(index_2)
# Out:
# [0 1 2 3 4]
#
# [0.4, 1.4, 2.4, 3.4, 4.4]

# %%
w = 0.4
index_1 = np.arange(len(labels))
index_2 = [i+w for i in range(len(labels))]
plt.figure()
plt.bar(index_1, men_means, w, label = "Men")
plt.legend()

# %%
w = 0.4
#index_1 = np.arange(len(labels))
#index_2 = [i+w for i in range(len(labels))]
plt.figure()
plt.bar(index_1, men_means, w, label = "Men")
plt.bar(index_2, women_means, w, label = "Women")
plt.legend()

# %%
#w = 0.4
#index_1 = np.arange(len(labels))
#index_2 = [i+w for i in range(len(labels))]
#plt.figure()
#plt.bar(index_1, men_means, w, label = "Men")
#plt.bar(index_2, women_means, w, label = "Women")
#plt.xticks(index_1+w/2)
#plt.legend()

# %%
w = 0.4
#index_1 = np.arange(len(labels))
#index_2 = [i+w for i in range(len(labels))]
#plt.figure()
plt.bar(index_1, men_means, w, label = "Men")
plt.bar(index_2, women_means, w, label = "Women")
plt.xticks(index_1+w/2, labels)
plt.legend()

# %%
data = pd.read_excel('Coeur.xlsx')

# %%
data.head()
# Out:
#    AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  DEPRESSION  \
# 0   40  homme   AA  140.0        289.0    0  Normal    172    Non         0.0
# 1   49  femme  DNA  160.0        180.0    0  Normal    156    Non         1.0
# 2   37  homme   AA  130.0        283.0    0      ST     98    Non         0.0
# 3   48  femme  ASY  138.0        214.0    0  Normal    108    Oui         1.5
# 4   54  homme  DNA  150.0        195.0    0  Normal    122    Non         0.0
#
#        PENTE  CŒUR
# 0  Ascendant     0
# 1       Plat     1
# 2  Ascendant     0
# 3       Plat     1
# 4  Ascendant     0

# %%
df = data.copy()

# %%
type(df['AGE'])
# Out:
# pandas.core.series.Series

# %%
type(x)
# Out:
# numpy.ndarray

# %%
plt.figure
plt.boxplot(df['AGE'])
plt.title('Ditribution de la variable Age')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.figure()
df.boxplot('AGE')
plt.title('Ditribution de la variable Age')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.figure()
df.boxplot('AGE', by='CŒUR')
# Out:
# <AxesSubplot:title={'center':'AGE'}, xlabel='CŒUR'>

# %%
plt.figure()
plt.hist(df['AGE'])
# Out:
# (array([ 12.,  37.,  86., 104., 148., 201., 175., 101.,  39.,  15.]),
#  array([28. , 32.9, 37.8, 42.7, 47.6, 52.5, 57.4, 62.3, 67.2, 72.1, 77. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure()
df.boxplot('AGE', by='SEXE')
# Out:
# <AxesSubplot:title={'center':'AGE'}, xlabel='SEXE'>

# %%
plt.figure()
df['AGE'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure()
plt.pie(df['ANGINE'].value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x1b2a2ad9f40>,
#   <matplotlib.patches.Wedge at 0x1b2a1add460>],
#  [Text(-0.32483074820260877, 1.050944805887604, ''),
#   Text(0.32483064980605275, -1.050944836300449, '')])

# %%
df['ANGINE'].value_counts()
# Out:
# Non    546
# Oui    371
# Name: ANGINE, dtype: int64

# %%
plt.figure()
df['ANGINE'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='ANGINE'>

# %%
plt.figure()
df['PENTE'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Quantitative vs Quantitative

# %%
plt.figure()
plt.scatter(df['AGE'], df['CHOLESTEROL'])

# %%
code_coeur = df['CŒUR'].astype('category').cat.codes
plt.figure()
df.plot.scatter('AGE', 'CHOLESTEROL', c=df['CŒUR'].astype('category').cat.codes)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='CHOLESTEROL'>

# %%
code_coeur = df['CŒUR'].astype('category').cat.codes
plt.figure()
df.plot.scatter('PAR', 'DEPRESSION', c=np.array(['blue','green'])[code_coeur])
# Out:
# <AxesSubplot:xlabel='PAR', ylabel='DEPRESSION'>

# %%
df.dtypes
# Out:
# AGE              int64
# SEXE            object
# TDT             object
# PAR            float64
# CHOLESTEROL    float64
# GAJ              int64
# ECG             object
# FCMAX            int64
# ANGINE          object
# DEPRESSION     float64
# PENTE           object
# CŒUR             int64
# dtype: object

# %%
list_qual=[]
list_quan=[]
for index in df.columns:
    if df[index].dtypes=='O':
        list_qual.append(index)
    else:
        list_quan.append(index)
#list_qual
list_quan
# Out:
# ['AGE', 'PAR', 'CHOLESTEROL', 'GAJ', 'FCMAX', 'DEPRESSION']

# %%
list_qual
# Out:
# ['SEXE', 'TDT', 'ECG', 'ANGINE', 'PENTE', 'CŒUR']

# %%
df['CŒUR']=df['CŒUR'].astype('object')

# %%
df.CŒUR.dtypesT
# Out:
# dtype('O')

# %%
df.select_dtypes(include='object').columns #donne les colonne qua
# Out:
# Index(['SEXE', 'TDT', 'ECG', 'ANGINE', 'PENTE', 'CŒUR'], dtype='object')

# %%
df.select_dtypes(include=['int','float']).columns
# Out:
# Index(['AGE', 'PAR', 'CHOLESTEROL', 'GAJ', 'FCMAX', 'DEPRESSION'], dtype='object')

# %%
df.select_dtypes(include=np.number).columns
# Out:
# Index(['AGE', 'PAR', 'CHOLESTEROL', 'GAJ', 'FCMAX', 'DEPRESSION'], dtype='object')

# %%
df.select_dtypes('object').columns #liste les colonnes qualitatives
# Out:
# Index(['SEXE', 'TDT', 'ECG', 'ANGINE', 'PENTE', 'CŒUR'], dtype='object')

# %%
plt.figure(figsize=(15,7))
#plt.bar(list_qual)
#plt.show()

# %%
list_qual
df[list_qual].dtypes
# Out:
# SEXE      object
# TDT       object
# ECG       object
# ANGINE    object
# PENTE     object
# CŒUR      object
# dtype: object

# %%
plt.figure(figsize=(17,7))
i=1
for element in list_qual:
    plt.subplot(1,7,i)
    df[element].value_counts().plot(kind='pie')
    i+=1
    plt.title(element)

# %%
for element in list_qual[0:5]:
    print(df[element].value_counts())
# Out:
# homme    725
# femme    193
# Name: SEXE, dtype: int64
# ASY    496
# DNA    203
# AA     173
# AT      46
# Name: TDT, dtype: int64
# Normal    548
# LVH       188
# ST        178
# Name: ECG, dtype: int64
# Non    546
# Oui    371
# Name: ANGINE, dtype: int64
# Plat          460
# Ascendant     393
# Descendant     63
# Name: PENTE, dtype: int64

# %%
df[element].value_counts()
# Out:
# Plat          460
# Ascendant     393
# Descendant     63
# Name: PENTE, dtype: int64

# %%
list_quan
# Out:
# ['AGE', 'PAR', 'CHOLESTEROL', 'GAJ', 'FCMAX', 'DEPRESSION']

# %%
plt.figure(figsize=(40,10))
i=1
for a in list_quan:
    plt.subplot(2,3,i)
    df[a].value_counts().plot(kind='hist',color='gray')
    i+=1
    plt.title(a)
