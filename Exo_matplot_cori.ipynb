# %% [markdown]
# # Exercice 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
coeur = pd.read_excel("Coeur.xlsx")
coeur.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   AGE          918 non-null    int64
#  1   SEXE         918 non-null    object
#  2   TDT          918 non-null    object
#  3   PAR          913 non-null    float64
#  4   CHOLESTEROL  917 non-null    float64
#  5   GAJ          918 non-null    int64
#  6   ECG          914 non-null    object
#  7   FCMAX        918 non-null    int64
#  8   ANGINE       917 non-null    object
#  9   DEPRESSION   918 non-null    float64
#  10  PENTE        916 non-null    object
#  11  CŒUR         918 non-null    int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 86.2+ KB

# %%
#8 Histogramme de 'AGE'
plt.hist(coeur[['AGE']], color="gray",edgecolor='white');
plt.title("Histogamme de la variable 'AGE'", fontsize=20);
plt.xlabel("AGE");

# %%
# Out:
# pandas.core.series.Series

# %%
#9 Histo de 'AGE' pour chaque 'COEUR'
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)

hist_0 = coeur.loc[coeur['CŒUR']==0,('AGE', 'CŒUR')]
plt.hist(hist_0['AGE'],edgecolor='white');

plt.subplot(1,2,2)

hist_1 = coeur.loc[coeur['CŒUR']==1,('AGE', 'CŒUR')]
plt.hist(hist_1['AGE'],edgecolor='white');

# %%
hist_1 = coeur.loc[coeur['CŒUR']==1,('AGE', 'CŒUR')]
plt.hist(hist_1['AGE'],edgecolor='white');

# %%
coeur
# Out:
#      AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 0     40  homme   AA  140.0        289.0    0  Normal    172    Non
# 1     49  femme  DNA  160.0        180.0    0  Normal    156    Non
# 2     37  homme   AA  130.0        283.0    0      ST     98    Non
# 3     48  femme  ASY  138.0        214.0    0  Normal    108    Oui
# 4     54  homme  DNA  150.0        195.0    0  Normal    122    Non
# ..   ...    ...  ...    ...          ...  ...     ...    ...    ...
# 913   45  homme   AT    NaN        264.0    0  Normal    132    Non
# 914   68  homme  ASY    NaN        193.0    1  Normal    141    Non
# 915   57  homme  ASY    NaN        131.0    0  Normal    115    Oui
# 916   57  femme   AA    NaN        236.0    0     LVH    174    Non
# 917   38  homme  DNA    NaN        175.0    0  Normal    173    Non
#
#      DEPRESSION      PENTE  CŒUR
# 0           0.0  Ascendant     0
# 1           1.0       Plat     1
# 2           0.0  Ascendant     0
# ...

# %%
#10
Coeur2=coeur.copy()
Coeur2["color"]=np.where(Coeur2.CŒUR==True,'orange','green')
plt.scatter(coeur['AGE'], coeur['DEPRESSION'],c=Coeur2.color);

# %%
# Out:
#      AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 0     40  homme   AA  140.0        289.0    0  Normal    172    Non
# 1     49  femme  DNA  160.0        180.0    0  Normal    156    Non
# 2     37  homme   AA  130.0        283.0    0      ST     98    Non
# 3     48  femme  ASY  138.0        214.0    0  Normal    108    Oui
# 4     54  homme  DNA  150.0        195.0    0  Normal    122    Non
# ..   ...    ...  ...    ...          ...  ...     ...    ...    ...
# 913   45  homme   AT    NaN        264.0    0  Normal    132    Non
# 914   68  homme  ASY    NaN        193.0    1  Normal    141    Non
# 915   57  homme  ASY    NaN        131.0    0  Normal    115    Oui
# 916   57  femme   AA    NaN        236.0    0     LVH    174    Non
# 917   38  homme  DNA    NaN        175.0    0  Normal    173    Non
#
#      DEPRESSION      PENTE  CŒUR  color
# 0           0.0  Ascendant     0  green
# 1           1.0       Plat     1    red
# ...

# %%
#coeur.plot.scatter("AGE", "DEPRESSION", c='CŒUR',cmap="plasma");
plt.scatter(coeur['AGE'],coeur["DEPRESSION"],c=coeur["CŒUR"],cmap="plasma")

# %%
#11
liste_qual = ['SEXE', 'TDT', 'ECG', 'ANGINE', 'PENTE', 'CŒUR', 'GAJ']
liste_qual
# Out:
# ['SEXE', 'TDT', 'ECG', 'ANGINE', 'PENTE', 'CŒUR', 'GAJ']

# %%
liste_quant = ['AGE', 'CHOLESTEROL', 'PAR', 'FCMAX', 'DEPRESSION']

# %%
for i in liste_quant:
    plt.hist(coeur[i], edgecolor='black', label=i)
    plt.title(i)
    plt.legend()
    plt.show()

# %%
colors = ['blue', 'red', 'orange', 'cyan', 'grey']

for index, libelle in enumerate(liste_quant):
    plt.figure(figsize=(10, 5))
    plt.hist(coeur[libelle], color=colors[index], label=libelle, edgecolor='black')
    plt.legend()


plt.show()

# %%
colors_1 = ['blue', 'red', 'orange', 'cyan', 'grey', 'green', 'brown']

for index, libelle in enumerate(liste_qual):
    plt.figure(figsize=(10, 5))
    x=coeur[libelle].value_counts()
    x.plot(kind='bar', label=libelle, color=colors_1[index])
#    plt.bar(coeur[libelle], color=colors[index], label=libelle, edgecolor='black', height=, width=5)
    plt.legend()


plt.show()

# %%
colors_1 = ['blue', 'red', 'orange', 'cyan', 'grey', 'green', 'brown']
i=1
plt.figure(figsize=(10, 5))
for index, libelle in enumerate(liste_qual):
    
    plt.subplot(2, 3, i)
    x=coeur[libelle].value_counts()
    x.plot(kind='bar', label=libelle, color=colors_1[index])
#    plt.bar(coeur[libelle], color=colors[index], label=libelle, edgecolor='black', height=, width=5)
    plt.legend()
    i+=1
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [92], in <cell line: 4>()
#       3 plt.figure(figsize=(10, 5))
#       4 for index, libelle in enumerate(liste_qual):
# ----> 6     plt.subplot(2, 3, i)
#       7     x=coeur[libelle].value_counts()
#       8     x.plot(kind='bar', label=libelle, color=colors_1[index])
#
# File ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py:1268, in subplot(*args, **kwargs)
#    1265 fig = gcf()
#    1267 # First, search for an existing subplot with a matching spec.
# -> 1268 key = SubplotSpec._from_subplot_args(fig, args)
#    1270 for ax in fig.axes:
#    1271     # if we found an axes at the position sort out if we can re-use it
#    1272     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1273         # if the user passed no kwargs, re-use
#
# ...

# %%
plt.figure(figsize=(30, 15))
plt.gcf().subplots_adjust(wspace=1, hspace=1)
i=1
for var in liste_qual:
    plt.subplot(3,3,i)
    x=coeur[var].value_counts()
    x.plot(kind='bar')
    plt.title(var, fontsize=40)
    #plt.xlabel(fontsize=20)
    plt.xticks(fontsize=20, rotation=45)
    #plt.ylabel(fontsize=20)
    plt.yticks(fontsize=20)

    i+=1

# %%
coeur.SEXE.value_counts()
# Out:
# homme    725
# femme    193
# Name: SEXE, dtype: int64

# %%
print(liste_quant)
# Out:
# ['AGE', 'CHOLESTEROL', 'PAR', 'FCMAX', 'DEPRESSION']
